# %% [markdown]
# #Instalando NBA_API e importando bibliotecas

# %%
pip install nba_api

# %%
import pandas as pd
import matplotlib.pyplot as plt
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.library.parameters import SeasonAll

# %% [markdown]
# # Definindo Váriaveis

# %%
teams = teams.get_teams()

# %%
players_dict = players.get_players()

# %%
#Visualizando dados dos jogadores
players_dict
# Out:
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
#  {'id': 76006,
# ...

# %%
#Visualizando dados dos times
teams
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %% [markdown]
# # Criando Data Frames

# %%
#Dataframe dos jogadores
df_players = pd.DataFrame(players_dict)

# %%
#Data Frame dos times
df_teams = pd.DataFrame(teams)

# %%
df_teams
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
df_players.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False

# %% [markdown]
# # Selecionando Atletas

# %%
#Selecionando Atletas = Curry e Kobe
players = ["Stephen Curry", "Kobe Bryant"]

# %%
#Filtrando jogadores pelo nome completo
df_id = df_players.query('full_name == @players')

# %%
df_id
# Out:
#          id      full_name first_name last_name  is_active
# 579     977    Kobe Bryant       Kobe    Bryant      False
# 944  201939  Stephen Curry    Stephen     Curry       True

# %%
df_Kobe = playergamelog.PlayerGameLog(player_id=df_id.iat[0,0], season = SeasonAll.all).get_data_frames()[0]

# %%
df_Curry = playergamelog.PlayerGameLog(player_id=df_id.iat[1,0], season = SeasonAll.all).get_data_frames()[0]

# %%
df_Kobe.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22015        977  0021501228  APR 13, 2016  LAL vs. UTA  W   42   22
# 1     22015        977  0021501209  APR 11, 2016    LAL @ OKC  L   19    4
# 2     22015        977  0021501195  APR 10, 2016    LAL @ HOU  L   27   10
# 3     22015        977  0021501184  APR 08, 2016    LAL @ NOP  L   22    4
# 4     22015        977  0021501172  APR 06, 2016  LAL vs. LAC  L   28    6
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   50   0.440  ...     4    4    4    1    1    2   1   60           7
# 1   12   0.333  ...     1    1    0    1    0    2   2   13         -24
# 2   22   0.455  ...     2    2    1    2    0    4   1   35         -10
# 3   15   0.267  ...     3    3    4    1    0    2   0   14         -16
# 4   19   0.316  ...     3    3    1    1    0    1   1   17         -15
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
# ...

# %%
df_Curry.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0     22023     201939  0022301182  APR 12, 2024  GSW vs. NOP  L   32   12
# 1     22023     201939  0022301169  APR 11, 2024    GSW @ POR  W   36    8
# 2     22023     201939  0022301155  APR 09, 2024    GSW @ LAL  W   32    7
# 3     22023     201939  0022301097  APR 05, 2024    GSW @ DAL  L   35    9
# 4     22023     201939  0022301113  APR 04, 2024    GSW @ HOU  W   31    9
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   23   0.522  ...     4    4    5    1    0    7   2   33          -8
# 1   22   0.364  ...     7    7    8    1    2    2   0   22           7
# 2    9   0.778  ...     7    7    8    1    2    1   2   23          13
# 3   23   0.391  ...     5    6    5    1    0    2   2   28          -5
# 4   14   0.643  ...     6    6    6    0    0    3   2   29          29
#
#    VIDEO_AVAILABLE
# 0                1
# 1                1
# 2                1
# ...

# %% [markdown]
# # Tratando Data Frame

# %%
nomes_colunas_curry = df_Curry.columns.tolist()
print(nomes_colunas_curry)
# Out:
# ['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE']

# %%
#Eliminando Colunas que não serão uteis
df_Curry = df_Curry.drop(["Player_ID", "Game_ID", "GAME_DATE", "MATCHUP", "WL", "MIN", "FGM", "FGA","FG3M", "FG3A", "FG3_PCT", "FTM", "FTA","OREB", "DREB", "PF", "PLUS_MINUS", "VIDEO_AVAILABLE"], axis = 'columns')

# %%
df_Curry
# Out:
#     SEASON_ID  FG_PCT  FT_PCT  REB  AST  STL  BLK  TOV  PTS
# 0       22023   0.522   1.000    4    5    1    0    7   33
# 1       22023   0.364   1.000    7    8    1    2    2   22
# 2       22023   0.778   0.750    7    8    1    2    1   23
# 3       22023   0.391   0.833    6    5    1    0    2   28
# 4       22023   0.643   1.000    6    6    0    0    3   29
# ..        ...     ...     ...  ...  ...  ...  ...  ...  ...
# 951     22009   0.500   0.000    4    6    0    0    5    9
# 952     22009   0.200   0.750    1    3    0    0    0    5
# 953     22009   0.500   0.000    5    9    2    0    1    7
# 954     22009   0.556   0.000    2    4    1    0    3   12
# 955     22009   0.583   0.000    2    7    4    0    2   14
#
# [956 rows x 9 columns]

# %%
#Eliminando Colunas que não serão uteis
df_Kobe = df_Kobe.drop(["Player_ID", "Game_ID", "GAME_DATE", "MATCHUP", "WL", "MIN", "FGM", "FGA","FG3M", "FG3A", "FG3_PCT", "FTM", "FTA","OREB", "DREB", "PF", "PLUS_MINUS", "VIDEO_AVAILABLE"], axis = 'columns')
df_Kobe
# Out:
#      SEASON_ID  FG_PCT  FT_PCT  REB  AST  STL  BLK  TOV  PTS
# 0        22015   0.440   0.833    4    4    1    1    2   60
# 1        22015   0.333   1.000    1    0    1    0    2   13
# 2        22015   0.455   1.000    2    1    2    0    4   35
# 3        22015   0.267   1.000    3    4    1    0    2   14
# 4        22015   0.316   1.000    3    1    1    0    1   17
# ...        ...     ...     ...  ...  ...  ...  ...  ...  ...
# 1341     21996   0.000   1.000    3    1    0    0    0    2
# 1342     21996   0.375   0.500    3    0    0    1    0   10
# 1343     21996   0.667   0.000    0    0    0    0    3    5
# 1344     21996   0.000   0.500    0    0    0    0    1    1
# 1345     21996   0.000   0.000    1    0    0    1    1    0
#
# [1346 rows x 9 columns]

# %%
#Tratando coluna Season_ID, para mostrar o ano correto
df_Kobe['SEASON_ID'] = df_Kobe['SEASON_ID'].str[1:5]
df_Curry['SEASON_ID'] = df_Curry['SEASON_ID'].str[1:5]

# %%
df_Kobe
# Out:
#      SEASON_ID  FG_PCT  FT_PCT  REB  AST  STL  BLK  TOV  PTS
# 0         2015   0.440   0.833    4    4    1    1    2   60
# 1         2015   0.333   1.000    1    0    1    0    2   13
# 2         2015   0.455   1.000    2    1    2    0    4   35
# 3         2015   0.267   1.000    3    4    1    0    2   14
# 4         2015   0.316   1.000    3    1    1    0    1   17
# ...        ...     ...     ...  ...  ...  ...  ...  ...  ...
# 1341      1996   0.000   1.000    3    1    0    0    0    2
# 1342      1996   0.375   0.500    3    0    0    1    0   10
# 1343      1996   0.667   0.000    0    0    0    0    3    5
# 1344      1996   0.000   0.500    0    0    0    0    1    1
# 1345      1996   0.000   0.000    1    0    0    1    1    0
#
# [1346 rows x 9 columns]

# %%
df_Curry
# Out:
#     SEASON_ID  FG_PCT  FT_PCT  REB  AST  STL  BLK  TOV  PTS
# 0        2023   0.522   1.000    4    5    1    0    7   33
# 1        2023   0.364   1.000    7    8    1    2    2   22
# 2        2023   0.778   0.750    7    8    1    2    1   23
# 3        2023   0.391   0.833    6    5    1    0    2   28
# 4        2023   0.643   1.000    6    6    0    0    3   29
# ..        ...     ...     ...  ...  ...  ...  ...  ...  ...
# 951      2009   0.500   0.000    4    6    0    0    5    9
# 952      2009   0.200   0.750    1    3    0    0    0    5
# 953      2009   0.500   0.000    5    9    2    0    1    7
# 954      2009   0.556   0.000    2    4    1    0    3   12
# 955      2009   0.583   0.000    2    7    4    0    2   14
#
# [956 rows x 9 columns]

# %%
#Agrupando dados de acordo com o ano
df_Curry = df_Curry.groupby('SEASON_ID').mean()
df_Kobe = df_Kobe.groupby('SEASON_ID').mean()

# %%
df_Kobe
# Out:
#              FG_PCT    FT_PCT       REB       AST       STL       BLK  \
# SEASON_ID
# 1996       0.352817  0.483775  1.859155  1.281690  0.690141  0.323944
# 1997       0.410873  0.700481  3.063291  2.518987  0.936709  0.506329
# 1998       0.471860  0.821440  5.280000  3.800000  1.440000  1.000000
# 1999       0.470061  0.824106  6.303030  4.893939  1.606061  0.939394
# 2000       0.457206  0.817485  5.867647  4.970588  1.676471  0.632353
# 2001       0.476100  0.837850  5.512500  5.475000  1.475000  0.437500
# 2002       0.452976  0.840439  6.878049  5.865854  2.207317  0.817073
# 2003       0.429385  0.821662  5.523077  5.076923  1.723077  0.430769
# 2004       0.433712  0.798848  5.939394  6.030303  1.303030  0.803030
# 2005       0.452187  0.835812  5.312500  4.500000  1.837500  0.375000
# 2006       0.460987  0.875922  5.701299  5.363636  1.441558  0.467532
# 2007       0.464744  0.822622  6.304878  5.378049  1.841463  0.487805
# ...

# %%
df_Kobe.reset_index(inplace=True)
df_Curry.reset_index(inplace=True)

# %% [markdown]
# # Criando Gráficos

# %%
plt.figure(figsize=(14,10))
plt.rcParams['xtick.labelsize'] = 10
plt.xticks(rotation=60)
plt.rcParams['ytick.labelsize'] = 12
plt.xlabel('Temporadas', size = 12)
plt.ylabel('Média de Rebotes por Jogo', size = 12)
plt.scatter(df_Kobe['SEASON_ID'], df_Kobe['REB'], marker = '.', alpha = 0.8, s = 100, color = 'orange', label = 'Kobe REB' )
plt.scatter(df_Curry['SEASON_ID'], df_Curry['REB'], marker = '.', alpha = 0.8, s = 100, color = 'blue', label = 'Curry REB' )
plt.plot(df_Kobe['SEASON_ID'], df_Kobe['REB'], color = 'orange',lw=1 )
plt.plot(df_Curry['SEASON_ID'], df_Curry['REB'],color = 'blue',lw=1 )
plt.axhline(df_Kobe['REB'].mean(), 0,1, color = 'orange', **{'ls':'--', 'lw': 0.8})
plt.axhline(df_Curry['REB'].mean(), 0,1, color = 'blue', **{'ls':'--', 'lw': 0.8})
plt.text(.4,1.8,"Início Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.text(8,4.4,"Início Carreira de Curry", bbox = {'facecolor': 'lightblue', 'alpha': 0.5})
plt.text(19.4,3.7,"Fim Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.annotate('média Kobe', xy=(-1,5.22), color='orange')
plt.annotate('média Curry', xy=(-1,4.78), color='blue')
plt.legend()
plt.grid(axis = 'x', color='grey', linewidth = '0.15')
plt.savefig('PranchetaNBA-P4-REB.png', format='png')

# %%
plt.figure(figsize=(14,10))
plt.rcParams['xtick.labelsize'] = 10
plt.xticks(rotation=60)
plt.rcParams['ytick.labelsize'] = 12
plt.xlabel('Temporadas', size = 12)
plt.ylabel('Média de Pontos por Jogo', size = 12)
plt.scatter(df_Kobe['SEASON_ID'], df_Kobe['PTS'], marker = '.', alpha = 0.8, s = 100, color = 'orange', label = 'Kobe PTS' )
plt.scatter(df_Curry['SEASON_ID'], df_Curry['PTS'], marker = '.', alpha = 0.8, s = 100, color = 'blue', label = 'Curry PTS' )
plt.plot(df_Kobe['SEASON_ID'], df_Kobe['PTS'], color = 'orange',lw=1 )
plt.plot(df_Curry['SEASON_ID'], df_Curry['PTS'],color = 'blue',lw=1 )
plt.axhline(df_Kobe['PTS'].mean(), 0,1, color = 'orange', **{'ls':'--', 'lw': 0.8})
plt.axhline(df_Curry['PTS'].mean(), 0,1, color = 'blue', **{'ls':'--', 'lw': 0.8})
plt.text(.4,7.7,"Início Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.text(8,17.5,"Início Carreira de Curry", bbox = {'facecolor': 'lightblue', 'alpha': 0.5})
plt.text(19.4,17.7,"Fim Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.annotate('média Kobe', xy=(-1,23.5), color='orange')
plt.annotate('média Curry', xy=(-1,24.7), color='blue')
plt.legend()
plt.grid(axis = 'x', color='grey', linewidth = '0.15')
plt.savefig('PranchetaNBA-P4-PTS.png', format='png')

# %%
plt.figure(figsize=(14,10))
plt.rcParams['xtick.labelsize'] = 10
plt.xticks(rotation=60)
plt.rcParams['ytick.labelsize'] = 12
plt.xlabel('Temporadas', size = 12)
plt.ylabel('Média de Assistência por Jogo', size = 12)
plt.scatter(df_Kobe['SEASON_ID'], df_Kobe['AST'], marker = '.', alpha = 0.8, s = 100, color = 'orange', label = 'Kobe AST' )
plt.scatter(df_Curry['SEASON_ID'], df_Curry['AST'], marker = '.', alpha = 0.8, s = 100, color = 'blue', label = 'Curry AST' )
plt.plot(df_Kobe['SEASON_ID'], df_Kobe['AST'], color = 'orange',lw=1 )
plt.plot(df_Curry['SEASON_ID'], df_Curry['AST'],color = 'blue',lw=1 )
plt.axhline(df_Kobe['AST'].mean(), 0,1, color = 'orange', **{'ls':'--', 'lw': 0.8})
plt.axhline(df_Curry['AST'].mean(), 0,1, color = 'blue', **{'ls':'--', 'lw': 0.8})
plt.text(.4,1.3,"Início Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.text(8.7,6.08,"Início Carreira de Curry", bbox = {'facecolor': 'lightblue', 'alpha': 0.5})
plt.text(19.4,2.68,"Fim Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.annotate('média Kobe', xy=(-1,4.8), color='orange')
plt.annotate('média Curry', xy=(-1,6.4), color='blue')
plt.legend()
plt.grid(axis = 'x', color='grey', linewidth = '0.15')
plt.savefig('PranchetaNBA-P4-AST.png', format='png')

# %%
plt.figure(figsize=(14,10))
plt.rcParams['xtick.labelsize'] = 10
plt.xticks(rotation=60)
plt.rcParams['ytick.labelsize'] = 12
plt.xlabel('Temporadas', size = 12)
plt.ylabel('Média de Roubos por Jogo', size = 12)
plt.scatter(df_Kobe['SEASON_ID'], df_Kobe['STL'], marker = '.', alpha = 0.8, s = 100, color = 'orange', label = 'Kobe STL' )
plt.scatter(df_Curry['SEASON_ID'], df_Curry['STL'], marker = '.', alpha = 0.8, s = 100, color = 'blue', label = 'Curry STL' )
plt.plot(df_Kobe['SEASON_ID'], df_Kobe['STL'], color = 'orange',lw=1 )
plt.plot(df_Curry['SEASON_ID'], df_Curry['STL'],color = 'blue',lw=1 )
plt.axhline(df_Kobe['STL'].mean(), 0,1, color = 'orange', **{'ls':'--', 'lw': 0.8})
plt.axhline(df_Curry['STL'].mean(), 0,1, color = 'blue', **{'ls':'--', 'lw': 0.8})
plt.text(.4,.65,"Início Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.text(8.7,1.95,"Início Carreira de Curry", bbox = {'facecolor': 'lightblue', 'alpha': 0.5})
plt.text(19.4,.9,"Fim Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.annotate('média Kobe', xy=(-1,1.39), color='orange')
plt.annotate('média Curry', xy=(-1,1.49), color='blue')
plt.legend()
plt.grid(axis = 'x', color='grey', linewidth = '0.15')
plt.savefig('PranchetaNBA-P4-STL.png', format='png')

# %%
plt.figure(figsize=(14,10))
plt.rcParams['xtick.labelsize'] = 10
plt.xticks(rotation=60)
plt.rcParams['ytick.labelsize'] = 12
plt.xlabel('Temporadas', size = 12)
plt.ylabel('Média de Bloqueios por Jogo', size = 12)
plt.scatter(df_Kobe['SEASON_ID'], df_Kobe['BLK'], marker = '.', alpha = 0.8, s = 100, color = 'orange', label = 'Kobe BLK' )
plt.scatter(df_Curry['SEASON_ID'], df_Curry['BLK'], marker = '.', alpha = 0.8, s = 100, color = 'blue', label = 'Curry BLK' )
plt.plot(df_Kobe['SEASON_ID'], df_Kobe['BLK'], color = 'orange',lw=1 )
plt.plot(df_Curry['SEASON_ID'], df_Curry['BLK'],color = 'blue',lw=1 )
plt.axhline(df_Kobe['BLK'].mean(), 0,1, color = 'orange', **{'ls':'--', 'lw': 0.8})
plt.axhline(df_Curry['BLK'].mean(), 0,1, color = 'blue', **{'ls':'--', 'lw': 0.8})
plt.text(.4,.32,"Início Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.text(8.12,.23,"Início Carreira de Curry", bbox = {'facecolor': 'lightblue', 'alpha': 0.5})
plt.text(16.4,.22,"Fim Carreira de Kobe", bbox = {'facecolor': 'gold', 'alpha': 0.5})
plt.annotate('média Kobe', xy=(-1,0.47), color='orange')
plt.annotate('média Curry', xy=(-1,0.24), color='blue')
plt.legend()
plt.grid(axis = 'x', color='grey', linewidth = '0.15')
plt.savefig('PranchetaNBA-P4-STL.png', format='png')

# %%
#https://medium.com/escurecendo-os-dados/kobe-x-lebron-uma-escolha-muito-dif%C3%ADcil-4937db9c3ef9
